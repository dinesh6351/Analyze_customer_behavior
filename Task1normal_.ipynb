# %%
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Hackathon_Working_Data.csv')

# %%
df.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0    M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1    M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2    M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3    M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4    M1        N1    4    T384      19.0  1.0   19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0     BUTTER MARGR  (4/94)                   BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                CHOCOLATE         CHOCOLATE PANNED         CHOCOLATE PANNED
# 3             PACKAGED TEA               MAIN PACKS               MAIN PACKS
# 4         ALL IODISED SALT            POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0               G C M M F           AMUL                AMUL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      26985 non-null  object
#  1   STORECODE  26985 non-null  object
#  2   DAY        26985 non-null  int64
#  3   BILL_ID    26985 non-null  object
#  4   BILL_AMT   26985 non-null  float64
#  5   QTY        26985 non-null  float64
#  6   VALUE      26985 non-null  float64
#  7   PRICE      26985 non-null  float64
#  8   GRP        26985 non-null  object
#  9   SGRP       26985 non-null  object
#  10  SSGRP      26985 non-null  object
#  11  CMP        26985 non-null  object
#  12  MBRD       26985 non-null  object
#  13  BRD        26985 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
df.isnull().sum()
# Out:
# MONTH        0
# STORECODE    0
# DAY          0
# BILL_ID      0
# BILL_AMT     0
# QTY          0
# PRICE        0
# GRP          0
# SGRP         0
# SSGRP        0
# CMP          0
# MBRD         0
# BRD          0
# dtype: int64

# %%
sns.distplot(df['PRICE'])
# Out:
# <ipython-input-20-1812ba0d7287>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PRICE'])
# <Axes: xlabel='PRICE', ylabel='Density'>

# %%
sns.countplot(data=df['MONTH'])
plt.show()

# %%
sns.countplot(data=df['STORECODE'])
# Out:
# <Axes: xlabel='count', ylabel='STORECODE'>

# %%
df.columns
# Out:
# Index(['MONTH', 'STORECODE', 'DAY', 'BILL_ID', 'BILL_AMT', 'QTY', 'VALUE',
#        'PRICE', 'GRP', 'SGRP', 'SSGRP', 'CMP', 'MBRD', 'BRD'],
#       dtype='object')

# %%
df.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0    M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1    M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2    M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3    M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4    M1        N1    4    T384      19.0  1.0   19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0     BUTTER MARGR  (4/94)                   BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                CHOCOLATE         CHOCOLATE PANNED         CHOCOLATE PANNED
# 3             PACKAGED TEA               MAIN PACKS               MAIN PACKS
# 4         ALL IODISED SALT            POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0               G C M M F           AMUL                AMUL
# ...

# %%
df.drop('VALUE',axis=1,inplace=True)

# %%
df.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  PRICE                      GRP  \
# 0    M1        N1    4    T375     225.0  1.0  225.0     BUTTER MARGR  (4/94)
# 1    M1        N1    4    T379      95.0  1.0   95.0  CONFECTIONERY - ECLAIRS
# 2    M1        N1    4    T381      10.0  1.0   10.0                CHOCOLATE
# 3    M1        N1    4    T382     108.0  1.0  108.0             PACKAGED TEA
# 4    M1        N1    4    T384      19.0  1.0   19.0         ALL IODISED SALT
#
#                       SGRP                    SSGRP                     CMP  \
# 0                   BUTTER                   SALTED               G C M M F
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS             PARLE PRODS
# 2         CHOCOLATE PANNED         CHOCOLATE PANNED  MONDELEZ INTERNATIONAL
# 3               MAIN PACKS               MAIN PACKS      GUJ TEA PROCESSORS
# 4            POWDERED SALT            POWDERED SALT               TATA CHEM
#
#             MBRD                 BRD
# ...

# %%
new_df=df.groupby(by='QTY').max()

# %%
new_df
# Out:
#         MONTH STORECODE  DAY BILL_ID  BILL_AMT    PRICE  \
# QTY
# 0.5        M2        N7   29   T4695     58.50    57.00
# 1.0        M3        N9   31    T999   7292.00  3150.00
# 2.0        M3        N9   31    T998   7292.00   799.00
# 3.0        M3        N9   31    T994   6111.01   445.00
# 4.0        M3        N9   31    T992   7048.00   420.00
# 5.0        M3        N9   31    T998   6111.01   445.00
# 6.0        M3        N9   31    T992   7292.00   445.00
# 7.0        M3        N9   30    T898   3739.00   195.00
# 8.0        M3        N9   31    T927   7292.00   350.00
# 9.0        M3        N9   31    T951   1323.00   140.00
# 10.0       M3        N9   31    T925   6040.00   225.00
# 11.0       M3        N9   30   T9251   3196.00   180.00
# 12.0       M3        N9   31    T972   4515.00   100.00
# 13.0       M3        N5   30    T971    245.00    10.00
# 14.0       M3        N7   30    T918    507.75     5.00
# 15.0       M3        N9   27    T950   1877.50    16.50
# ...

# %%
sns.histplot(df['PRICE'],bins=30,kde=True)
# Out:
# <Axes: xlabel='PRICE', ylabel='Count'>

# %%
plt.figure(figsize=(25,6))
sns.boxplot(x='GRP',y='PRICE',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  PRICE                      GRP  \
# 0    M1        N1    4    T375     225.0  1.0  225.0     BUTTER MARGR  (4/94)
# 1    M1        N1    4    T379      95.0  1.0   95.0  CONFECTIONERY - ECLAIRS
# 2    M1        N1    4    T381      10.0  1.0   10.0                CHOCOLATE
# 3    M1        N1    4    T382     108.0  1.0  108.0             PACKAGED TEA
# 4    M1        N1    4    T384      19.0  1.0   19.0         ALL IODISED SALT
#
#                       SGRP                    SSGRP                     CMP  \
# 0                   BUTTER                   SALTED               G C M M F
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS             PARLE PRODS
# 2         CHOCOLATE PANNED         CHOCOLATE PANNED  MONDELEZ INTERNATIONAL
# 3               MAIN PACKS               MAIN PACKS      GUJ TEA PROCESSORS
# 4            POWDERED SALT            POWDERED SALT               TATA CHEM
#
#             MBRD                 BRD
# ...

# %%
df2=df.groupby(by='STORECODE').mean()
# Out:
# <ipython-input-130-f3007fe26f98>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2=df.groupby(by='STORECODE').mean()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df2)
# Out:
# <Axes: xlabel='STORECODE'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df2)
# Out:
# <Axes: xlabel='STORECODE'>

# %%
df.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  PRICE                      GRP  \
# 0    M1        N1    4    T375     225.0  1.0  225.0     BUTTER MARGR  (4/94)
# 1    M1        N1    4    T379      95.0  1.0   95.0  CONFECTIONERY - ECLAIRS
# 2    M1        N1    4    T381      10.0  1.0   10.0                CHOCOLATE
# 3    M1        N1    4    T382     108.0  1.0  108.0             PACKAGED TEA
# 4    M1        N1    4    T384      19.0  1.0   19.0         ALL IODISED SALT
#
#                       SGRP                    SSGRP                     CMP  \
# 0                   BUTTER                   SALTED               G C M M F
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS             PARLE PRODS
# 2         CHOCOLATE PANNED         CHOCOLATE PANNED  MONDELEZ INTERNATIONAL
# 3               MAIN PACKS               MAIN PACKS      GUJ TEA PROCESSORS
# 4            POWDERED SALT            POWDERED SALT               TATA CHEM
#
#             MBRD                 BRD
# ...

# %%
df['BILL_AMT'].mean()
# Out:
# 278.75420604039283

# %%
df['PRICE'].mean()
# Out:
# 52.81298239762832

# %%
df['BILL_ID'].value_counts()
# Out:
# T1521    44
# T7794    35
# T631     33
# T3293    31
# T577     30
#          ..
# T7611     1
# T7604     1
# T7595     1
# T7594     1
# T2845     1
# Name: BILL_ID, Length: 6424, dtype: int64

# %% [markdown]
# #Bill_id

# %%
df3=df.groupby(by='BILL_ID')

# %%
df3.head()
# Out:
#       MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  PRICE  \
# 0        M1        N1    4    T375     225.0  1.0  225.0
# 1        M1        N1    4    T379      95.0  1.0   95.0
# 2        M1        N1    4    T381      10.0  1.0   10.0
# 3        M1        N1    4    T382     108.0  1.0  108.0
# 4        M1        N1    4    T384      19.0  1.0   19.0
# ...     ...       ...  ...     ...       ...  ...    ...
# 26980    M3       N10   31   T5999      10.0  1.0   10.0
# 26981    M3       N10   31   T6007      88.0  1.0   10.0
# 26982    M3       N10   31   T6007      88.0  2.0   10.0
# 26983    M3       N10   31   T6007      88.0  1.0   58.0
# 26984    M3       N10   31   T6013      15.0  1.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# 1         CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                       CHOCOLATE         CHOCOLATE PANNED
# ...

# %%
plt.figure(figsize=(25,8))
sns.scatterplot()
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-42ac614a686a> in <cell line: 2>()
#       1 plt.figure(figsize=(25,8))
# ----> 2 sns.scatterplot(data=df3)
#       3 plt.xticks(rotation=90)
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     608 ):
#     609
# --> 610     p = _ScatterPlotter(
#     611         data=data,
#     612         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     389         )
#     390
# --> 391         super().__init__(data=data, variables=variables)
#     392
#     393         self.legend = legend
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df3)
# Out:
# <Axes: xlabel='BILL_ID'>
